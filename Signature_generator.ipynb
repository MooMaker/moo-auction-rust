# %%
#!pip install web3

# %%
#Order hash is generated by function "getEthSignedMessageHash" in our smart contract. And needs to be passed here
order_hash = '0x2f60b57128c5ca893e54829e8f0d7ebb88b78702a80e7e68b8a15239ab47e808'
#Private key needs to be from the same account as "maker" in order data. 
#Currently this address is used as maker and signer for testing 0x40Eb9614Ba89633B6D0e9fD8177E86D5971CD596
private_key = 'c566a08f7be78ba35ce8da6be052917a3a8d1ec22011808a30184a00b727a777' 
signed_order = Account.signHash(order_hash, private_key)
signed_order.signature.hex()

#the generated signature will need to be passed in"swap" functon in our contract
# Out:
# '0x5416326a1a93dbbf1fe66664b6bcb6dc514688d7381a9aa55a967faa7f5d7b38625d3f80c778cabdb848e58149b02445f2484d1046437e2e089beedd271a8bce1b'
